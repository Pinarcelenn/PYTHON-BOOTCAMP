# %%
class Library:
    def __init__(self):
        self.file = open("books.txt", "a+")

    def __del__(self):
        self.file.close()

    def list_books(self):
        self.file.seek(0)
        books = self.file.readlines()
        for book in books:
            book_info = book.strip().split(',')
            print(f"Book: {book_info[0]}, Author: {book_info[1]}")

    def add_book(self):
        title = input("Enter the book title: ")
        author = input("Enter the author's name: ")
        release_year = input("Enter the release year: ")
        pages = input("Enter the number of pages: ")

        book_info = f"{title},{author},{release_year},{pages}\n"
        self.file.write(book_info)
        print("Book added successfully!")

    def remove_book(self):
        title = input("Enter the title of the book you want to remove: ")
        self.file.seek(0)
        books = self.file.readlines()
        new_books = []
        for book in books:
            if title not in book:
                new_books.append(book)
        self.file.seek(0)
        self.file.truncate()
        self.file.writelines(new_books)
        print("Book removed successfully!")



lib = Library()


while True:
    print("*** MENU ***")
    print("1) List Books")
    print("2) Add Book")
    print("3) Remove Book")
    print("4) Quit")

    choice = input("Enter your choice: ")

    if choice == "1":
        lib.list_books()
    elif choice == "2":
        lib.add_book()
    elif choice == "3":
        lib.remove_book()
    elif choice == "4":
        break
    else:
        print("Invalid choice. Please choose again.")
# Out:
# *** MENU ***
# 1) List Books
# 2) Add Book
# 3) Remove Book
# 4) Quit
# Enter your choice: 2
# Enter the book title: OLMAYALI
# Enter the author's name: ORUÇ ARUOBA
# Enter the release year: 2003
# Enter the number of pages: 152
# Book added successfully!
# *** MENU ***
# 1) List Books
# 2) Add Book
# 3) Remove Book
# 4) Quit
# Enter your choice: 1
# Book: OLMAYALI, Author: ORUÇ ARUOBA
# *** MENU ***
# 1) List Books
# 2) Add Book
# 3) Remove Book
# 4) Quit
# Enter your choice: 2
# Enter the book title: OL AN
# Enter the author's name: ORUÇ ARUOBA
# Enter the release year: 1994
# Enter the number of pages: 219
# Book added successfully!
# *** MENU ***
# 1) List Books
# 2) Add Book
# 3) Remove Book
# 4) Quit
# Enter your choice: 1
# Book: OLMAYALI, Author: ORUÇ ARUOBA
# Book: OL AN, Author: ORUÇ ARUOBA
# *** MENU ***
# 1) List Books
# 2) Add Book
# 3) Remove Book
# 4) Quit
# Enter your choice: 2
# Enter the book title: UZAK
# Enter the author's name: ORUÇ ARUOBA
# Enter the release year: 1995
# Enter the number of pages: 133
# Book added successfully!
# *** MENU ***
# 1) List Books
# 2) Add Book
# 3) Remove Book
# 4) Quit
# Enter your choice: 1
# Book: OLMAYALI, Author: ORUÇ ARUOBA
# Book: OL AN, Author: ORUÇ ARUOBA
# Book: UZAK, Author: ORUÇ ARUOBA
# *** MENU ***
# 1) List Books
# 2) Add Book
# 3) Remove Book
# 4) Quit
# Enter your choice: 2
# Enter the book title: YAKIN
# Enter the author's name: ORUÇ ARUOBA
# Enter the release year: 1997
# Enter the number of pages: 162
# Book added successfully!
# *** MENU ***
# 1) List Books
# 2) Add Book
# 3) Remove Book
# 4) Quit
# Enter your choice: 1
# Book: OLMAYALI, Author: ORUÇ ARUOBA
# Book: OL AN, Author: ORUÇ ARUOBA
# Book: UZAK, Author: ORUÇ ARUOBA
# Book: YAKIN, Author: ORUÇ ARUOBA
# *** MENU ***
# 1) List Books
# 2) Add Book
# 3) Remove Book
# 4) Quit
